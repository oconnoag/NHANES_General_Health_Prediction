# %% [markdown]
# <div align='center'>
#     <h1>Predicting Subjective Accessment of General Health</h1>
#     Flor Cabral, Alijah O'Connor <br>
#     CSCI3022 - Data Science, Spring 2019
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import patsy

import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, LinearRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
from sklearn.preprocessing import scale
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (precision_score, balanced_accuracy_score, 
                             classification_report, make_scorer, confusion_matrix)


# Module for extra functions we wrote
from extra_functions.functions import (general_health_reclasser, visualize, visualize_categorical, kde_by_category,
                                       print_metrics, data_splitter, scaled_data_splitter,
                                       predict_w_treshold, grid_search_wrap)

from IPython.display import clear_output

# %% [markdown]
# # I. Table of Contents
# <a href='#II.-Introduction'>II. Introduction</a><br>
# <a href='#III.-Exploring-Laboratory-based-Data'>III. Exploring Laboratory-based Data</a><br>
# <a href='#IV.-Modeling-with-Lab-based-Data'>IV. Modeling with Lab-based Data</a><br>
# <a href='#V.-Exploring-Sociological-based-Data'>V. Exploring Sociological-based Data</a><br>
# <a href='#VI.-Modeling-with-Sociological-based-Data'>VI. Modeling with Sociological-based Data</a><br>
# <a href='#VII.-Modeling-with-Combined-Data'>VII. Modeling with Combined Data</a><br>
# <a href='#VIII.-Conclusion-&-Discussion'>VIII. Conclusion, Discussion, and Future Plans</a><br>
# <a href='#IX.-References'>IX. References</a><br>

# %% [markdown]
# # II. Introduction

# %% [markdown]
# Assessing subjective feelings (e.g. general health, quality of life, etc) has been an important task in medicine for as long as the profession has existed.  Considering that a core goal in medicine seeks to restore positive subjective perceptions and/or prevent negative subjective perceptions in the subjects, the salience of accurate measurements is not hard to overstate.  As with any subjective assessment, however, a number of biases can introduce a large amount of arbitrary variance to the measurements.  There have been several attempts to standardize measurements of subjective experience using various survey questions--one example is called the Nottingham Health Profile, an attempt to measure "quality of life" (Hunt, 1985).  To expand to the existing list of subjective-to-objective mapping, we are attempting to predict a particular subjective measurement ("General Health") from CDC health data by building statistical models with laboratory-based data, sociological-based data, and combined subsets of the two.  The general hypothesis for this project is given a certain set of information about a patient, we can determine/predict how they feel about their health (by classifying them into a corresponding category), without explicitly asking them.

# %% [markdown]
# ## II.a Data Description

# %% [markdown]
# #### NHANES Overview
# The data used in this study is compiled and propogated by the CDC under the program name National Health and Nutrition Examination Survey (which will herein be referred to as NHANES).  The NHANES program operates annually (though with different pools of participants) with the goal of assessing health and nutrition of the denizens of America.  The data produced by the program is unique because it utilizes biochemical laboratory-based methods, questionnaires, diet, external body measures, and demographics.  This abundance of data is attractive for statisticians and data scientists (or students of the fields, like us) for generating models for all sorts of different outcomes using a number of measurements (referred to as features in data science).
#
# #### Data acquistion
# The specific NHANES data used herein is a subset of files and fields from the 2015-2016 collection (https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?BeginYear=2015).  This is the most recent release of NHANES data, as it takes years for the researchers to organize, clean, and verify the data from a particular year.
# As noted previously, the NHANES data is broken up into several categories (e.g. demographics, laboratory, etc), and each category is subsequently broken up into a number of files which are made up a number of columns corresponding to the particular measurement.  Interestingly, the data files within each category are released to the public in XPT format, which cannot readily be used for analysis in Pandas.  To be able to use these datafiles in our study, we wrote a shell script that coverts the xpt files to csv.
#
# We have placed the converted files in a github repository here: https://github.com/oconnoag/NHANES_Data.  This repository also contains the compiled files, which will be described shortly.  We opted for having separate repositories for the data and the analyses, because (1) if anyone else would like the download the data themselves in csv format, they can easily clone or zip the repository and (2) this architecture allows for easy reading of the csv files from Github, so there is no need for someone to download the entire datasets to their local machine to view our analysis.
#
# #### Selecting intial features to compile for consideration
# For the compiled data (i.e. the data that we actually analyzed for incorporation in our models), we decided to choose a subset of fators that we surmised would correlate with a subject's general health.  In the data setup files (found here:  https://github.com/oconnoag/NHANES_Data/tree/master/compiled_data), the features we divided between the authors of this study (Alijah and Flor).  Alijah would choose and explore data from the laboratory category, and Flor would choose and explore data from the questionnaire and demographics categories.  By including data from these two disparate fields we get to utilize both quantitative and qualitative features.  What's more, this approach serves as an initial test to target specific factors out of intuition (sort of a proof of concept); however, once these original models are constructed, we may switch gears and generalize our approach by including many more factors.
#
# #### General Health
# The general_health field is originally coded as the "HSD010" column in the /Questionnaire/HSQ_I ("General Health Status") file.  The measurements come from subjects answering the question:  "Would you say {your/SP's} health in general is {List Options}?".  The answers are broken up into 5 levels: 1, 2, 3, 4, 5 corresponding to "Excellent", "Very Good", "Good", "Fair", and "Poor", respectively.  These categories were further mapped to 3 classes, due to poor model performance (likely caused by extreme class inbalances).  The mapping was {classes 1-2: 1, class 3: 2, classes 4-5: 3} and were described as {1: "Better", 2: "Good", 3: "Worse"}.
#
# #### Laboratory Features Considered
# | Filename_NHANES | Filename_Project | Feature_Name_NHANES | Feature_Name_Project | Description |
# |------|------|------|------|------|
# |   BIOPRO_I  | standard_biochem_profile | LBXSBU | Blood Urea Nitrogen  | Measured from blood in mg/dL |
# |   BIOPRO_I  | standard_biochem_profile | LBXSC3SI | Bicarbonate  | Measured from serum in mmol/L |
# |   BIOPRO_I  | standard_biochem_profile | LBXSCA | Total Calcium | Measured from serum in mg/dL
# |   BIOPRO_I  | standard_biochem_profile | LBXSCH | Cholesterol | Measured from serum in mg/dL
# |   BIOPRO_I  | standard_biochem_profile | LBXSCLSI | Chloride | Measured from serum in mmol/L
# |   BIOPRO_I  | standard_biochem_profile | LBXSGL | Glucose | Measured from serum in mg/dL
# |   BIOPRO_I  | standard_biochem_profile | LBXSIR | Iron | Measured from serum in ug/dL
# |   BIOPRO_I  | standard_biochem_profile  | LBXSKSI | Potassium | Measured from serum in mmol/L
# |   BIOPRO_I  | standard_biochem_profile  | LBXSNASI | Sodium | Measured from serum in mmol/L
# |   BIOPRO_I  | standard_biochem_profile  | LBXSTP | Total Protein | Measured from serum in g/dL
# |   BIOPRO_I  | standard_biochem_profile  | LBXSTR | Triglycerides | Measured from serum in mg/dL
# |   BIOPRO_I  | standard_biochem_profile  | LBXSUA | Uric acid | Measured from serum in mg/dL
# |   TST_I  | sex_steroid_hormone | 	LBXTST | Testosterone | Measured from serum in ng/dL
# |   TST_I  | sex_steroid_hormone | 	LBXEST | Estradiol | Measured from serum in pg/dL
# |   TST_I  | sex_steroid_hormone | LBXSHBG | Sex Hormone Binding Globulin (SHBG) | Measured from serum in nmol/L
# |   GHB_I  | glycohemoglobin | LBXGH | glycohemoglobin | Measured from serum as a percentage (%)
#
#
# #### Questionnaire/Demographic Features
#
# | Filename_NHANES | Filename_Project | Feature_Name_NHANES | Feature_Name_Project | Description |
# |------|------|------|------|------|
# |   DEMO_I  | demographics | RIDAGEYR | Age  | Age in years |
# |   DEMO_I  | demographics | DMDHHSIZ | People in Household  | Values range 1-7 |
# |   DEMO_I  | demographics | INDHHIN2 | Annual household income | Values range 1-15, representing incomes 0 to $100,000+
# |   DBQ_I  | diet_and_behavior | DBQ700 | Healthy Diet | Values range from 1-5
# |   DBQ_I  | diet_and_behavior | DBD900 | Number of fast food meals past 7 days | Values range from 0 to 21+
# |   DBQ_I  | diet_and_behavior | DBD910 | Number of frozen meals past 30 days | Values range from 0 to 90+
# |   PAQ_I  | physical_activity | PAQ635 | Walk or bike | Answers are Y/N
# |   PAQ_I  | physical_activity  | PAQ650 | Vigorous recreational activities per week | Answers are Y/N
# |   PAQ_I  | physical_activity  | PAQ680 | Minutes of sedentary activity per day | Values range from 0 to 1380
# |   BMX_I  | body_measures  | BMXBMI | Body Mass Index | Measured in kg/m**2

# %% [markdown]
# ## II.b Analysis/Modeling Descriptions

# %% [markdown]
# ### Data Cleaning
# In order to be able to use our data for model generation (and some visualizations like pairplot), there cannot be nan values in any of the columns.  This led to removing some initial features that didn't have enough datapoints from the start. We also removed any conceptually meaningless values from our sets, such as "Don't know" and "Refused". Once we had features from files that had a sufficient # of entries (>6000), we removed all entries that contain any nan values.  For the laboratory set, this reduced the size to ~5500 complete subject profiles. For the sociological/demographic set, the size was reduced to ~4000. Outlier culling was not undertaken in this part of the project, because we don't know just how particular values will affect the construction of the models.  Biology is messy, so it's difficult to determine what constitutes an outlier; however, we may pick some threshold for distance (in standard deviations from the mean) if certain values seem to be skewing the data in drastic ways (like perhaps glucose measurements).
#
# ### Feature Culling
# To better focus our attention on certain features, we employed a method of culling the number of features based on the correlation coefficients between each feature and the response variable, 'general_health.'  A threshold of |0.05| was chosen arbitrarily to remove a number of features from the analysis.
#
# ### Exploratory Data Analysis
# For each feature in each set of data (i.e. lab or sociological), visualizations were generated to better understand how the data is distributed in each class and also to see the relationship between a feature and 'general_health.'  What's more, a colinearity/inter-feature-correlation assessment was conducted for each using pairplots and heatmaps.
# Note that a external module was utilized for modularizing/organizing this project, so details regarding some of the visualizations can only be found within the modules (extra_functions).
#
# ### Models Tested
# Our approach lends it well to classificiation, in the machine learning parlance, and because this is a multi-level classification problem, a couple of different models could be considered:
#
# *Weak Learners:*
#
# * **Linear Regression-based Classification** - A paramteric regression technique used ordinarily for predicting quantitative outputs.  Although not a typical classifier, linear regression can be altered to produce classification outputs.  For example, the model is fit and the predictions are rounded to the nearest integer in the class set.
#
#
# * **K-Nearest Neighbors (KNN)** - A nonparameteric model that classifies points based on their proximity (locality) to other existing/training data points.  Provides very flexible decision boundaries; therefore, can better classify points in datasets that have highly non-linear boudaries.  Data may need to be scaled though, because this model suffers from multi-dimensional loss-of-locality (also known as the "curse of dimensionality").
#
#
# * **Logistic Regression** - Logistic Regression serves to solve classification problems; it classifies the data by considering outcome variables on extreme ends, and drawing a logarithmic line that distinguishes between them. Its underlying technique is close to that of Linear Regression; however, it refers to the Logit function that is used in this method of classification. A logistic function is a Sigmoid function that takes any real value between 0 and 1. Its curve is constructed using the natural logarithm of the “odds” of the target variable, rather than the probability. Moreover, the predictors do not have to be normally distributed or have equal variance in each group.
#
#
# * **Discriminant Analyses (LDA/QDA)** -  Discriminant Analyses are similiar in setup as Logistic Regression, except they use Bayesian stastistics to determine their classifications. This is one of the most popular approaches for classification problems dealing with more than two classes.  One interesting feature of a discriminant analysis is the the discriminant plot, which can plot the classification bounds in K - 1 dimensional space (where K is the number of classes being considered).  In our problem here, since we have 5 classes, a 4D would be hard to visualize; however, there are techniques for reducing the space to a "best" 2D plot.  Moreover, if we were to reduce the number of classes to 3 (say, Levels 1-2 become "Above Average", Level 3 becomes "Average", and levels 4-5 become "Below Average"), then we can easily see how our classification boundaries are being drawn.  More on class reduction in the discussion section.
#
#
# *Ensemble Methods:*
#
# * **Overview - ** Ensemble Methods are techniques that create multiple models and then combine them to produce improved results. They usually produce more accurate solutions than a single model would, by combining a diverse set of individual models (learners) to improve on the stability and predictive power of the model.
#
#
# * **Random Forest (Bagging)** - a technique that extends on another technique called a decision tree.  Decision trees on their own tend to be very good at working with the training data, but are generally less great with the test data (i.e. they overfit the training data).  Random Forests provide a method for taking the predictive power of a decision tree while adding flexibility to it by using another technique called bagging (<u>b</u>ootstrapping the data and <u>ag</u>gregat<u>ing</u>).  Breifly, the process refers to simulating new data from the original data and then creating many decision trees with a certain subset of the total features (hence the name, Random Forest).  Using all of those decision trees, new data can be inputted and adjudicated (classified) by the the jury of trees in the forest.  The class with the highest number of votes gets the classification.  Interestingly, one can obtain an "Feature Importance" report from many popular machine learning packages when generating Random Forests, allowing one to assess the contribution of each of the features to the classifications (Donges, 2018).
#
#
# * **Voting Classifer (Stacking)** - This method creates separate models with the same dataset and aggregates their predictions. They allow for many weak-learners to participate in the final "classification" of a datapoint, as they are built from many independent weak learners.  Predictions made by the sub-models can be assigned weights; stacked aggregation can be used to learn how to weigh these predictions in the most optimal way. Classifiers are trained on the same data; if they are independent, the ensemble can perform better than individual low performing classifiers. There are two popular subsets of voting: hard and soft.  Hard voting refers to counting the number of votes for each class that a model has made, and then choosing the majority class.  Soft Voting uses a cumulative probability for each class to determine which class to choose.
#
#
# * **Gradient Boosting (Boosting)** - a powerful ensemble technique for building predictive models, where the predictors are not made independently, but sequentially. It relies on the intuition that the overall prediction error is minimized by combining previous models. For this, we set the target outcomes for each case in the data, which depends on how much changing that case’s prediction impacts the overall prediction error. Basically, if a small change in the prediction for a case significantly reduces the error, the next target outcome for that case is a high value. Otherwise, if it causes no change in error, the next target outcome of that case is zero. In the first scenario, predictions from the new model that are close to its targets will reduce the error, while in the second changes in this prediction will not do so. This technique allows each new model to take a step in the direction that minimizes prediction error, in the space of possible predictions for each training case.
#
# Moreover, as mentioned previously, we are built different models in sets using (a) laboratory data only, (b) sociological data only, and (c) finally the combined datasets.
#
# ### Modeling Considerations, Pipeline, and Assessment
#
# We generated a model pipeline to automate data splitting, model construction (with hyperparamter optimization), metric scraping, and performance assessing through plotting (boxplots).  Each model above was constructed 25-times (for each section, respectively) using a different training/test data split on each iteration.  The datasplits were stratified, meaning that each split received the same percentage of each class observation as the full data class-priors.  The hyperparamters were optimized to the dataset using Scikit-learn's GridSearch procedure with 5-fold cross validation to optimize the 'balanced accuracy' of the model.  Balanced accuracy was chosen as the metric, because it is an unweighted assessment of the model's accuracy; this bodes well for the general health data, because the classes are initially unbalanced.  Precision of the models were also assessed to determine if the models were performing well in each category.  It should be noted that a high precision wasn't necessarily favorable (consider, the case were only 10 predictions of class 10 were made and all 10 of those correct; because the precision was macro-averaged, that class has the same weight as the larger classes, so could heavy skew the overall impression of this metric).
#
# Certain alterations to the data/models were also made to assess the performance of the models at their full potential.  For example, KNN was run with both unscaled and scaled data (to account for the 'curse of dimensionality', since several features (particularly in the lab-data) were magnitudes greater than others.  Another consideration for the models that operate through a probability-based classification routine, was changing the threshold for classifying a point as class '3' (worse) to 27%.  The class with the highest predicted percentage is typically given the classification, so this alteration classifies more points to the 3 category.  27% was used as the altered threshold for all of these alterations; however, it should be noted that if a practitioner wanted to use this method in their final models, they could further optimize that percentage.

# %% [markdown]
# # III. Exploring Laboratory-based Data

# %%
lab_data_url = 'https://raw.githubusercontent.com/oconnoag/NHANES_Data/master/compiled_data/alijah_compiled_raw.csv'
lab_raw_data = pd.read_csv(lab_data_url)

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Column Renaming

# %%
lab_processed_data_a = lab_raw_data.copy()

# %%
lab_processed_data_b = lab_processed_data_a.rename(columns={'HSD010': 'general_health',
                                                    'LBXTST': 'testosterone',
                                                    'LBXEST': 'estradiol',
                                                    'LBXSHBG': 'sex_hormone_binding_globulin',
                                                    'LBXGH': 'glycohemoglobin',
                                                    'LBXSBU': 'blood_urea_nitrogen',
                                                    'LBXSC3SI': 'bicarbonate',
                                                    'LBXSCA': 'calcium',
                                                    'LBXSCH': 'cholesterol',
                                                    'LBXSCLSI': 'chloride', 
                                                    'LBXSGL': 'glucose',
                                                    'LBXSIR': 'iron',
                                                    'LBXSKSI': 'potassium',
                                                    'LBXSNASI': 'sodium',
                                                    'LBXSTP': 'total_protein',
                                                    'LBXSTR': 'triglycerides',
                                                    'LBXSUA': 'uric_acid'})

# %%
lab_processed_data_c = lab_processed_data_b.copy()
lab_processed_data_c['general_health'] = lab_processed_data_b['general_health']\
                                            .apply(lambda x: general_health_reclasser(x))

# %% [markdown]
# #### Cleaning Data

# %%
lab_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6744 entries, 0 to 6743
# Data columns (total 18 columns):
# SEQN        6744 non-null float64
# HSD010      6166 non-null float64
# LBXTST      6235 non-null float64
# LBXEST      6186 non-null float64
# LBXSHBG     6039 non-null float64
# LBXGH       6326 non-null float64
# LBXSBU      6255 non-null float64
# LBXSC3SI    6257 non-null float64
# LBXSCA      6257 non-null float64
# LBXSCH      6254 non-null float64
# LBXSCLSI    6257 non-null float64
# LBXSGL      6257 non-null float64
# LBXSIR      6253 non-null float64
# LBXSKSI     6257 non-null float64
# LBXSNASI    6257 non-null float64
# LBXSTP      6253 non-null float64
# LBXSTR      6254 non-null float64
# LBXSUA      6254 non-null float64
# dtypes: float64(18)
# memory usage: 948.5 KB

# %%
lab_processed_data = lab_processed_data_c.copy()

# %%
# Drop any subject that did not have a particular lab test performed
lab_processed_data = lab_processed_data.dropna()

# %%
lab_processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5503 entries, 0 to 6743
# Data columns (total 18 columns):
# SEQN                            5503 non-null float64
# general_health                  5503 non-null float64
# testosterone                    5503 non-null float64
# estradiol                       5503 non-null float64
# sex_hormone_binding_globulin    5503 non-null float64
# glycohemoglobin                 5503 non-null float64
# blood_urea_nitrogen             5503 non-null float64
# bicarbonate                     5503 non-null float64
# calcium                         5503 non-null float64
# cholesterol                     5503 non-null float64
# chloride                        5503 non-null float64
# glucose                         5503 non-null float64
# iron                            5503 non-null float64
# potassium                       5503 non-null float64
# sodium                          5503 non-null float64
# ...

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### General Health Distribution
# - In the 5 level set up, there are many fewer 1's and 5's than 3's

# %%
lab_processed_data['general_health'].hist(grid=False, bins=np.arange(0,7,1)-0.5, ec='k')
plt.xlim([0,4])
plt.title('Breakdown (# of subjects in each)\n of General Health Levels')
plt.ylabel("Freq")
plt.xlabel("Current Health Level")
plt.xticks(np.arange(1,4), ['1 - Better', '2 - Good', '3 - Worse'],
          rotation=90);

# %% [markdown]
# #### Column Histograms

# %%
pd.DataFrame.hist(lab_processed_data.drop('SEQN', axis=1), figsize = [15,15], edgecolor='k', grid=False);

# %% [markdown]
# ### Feature Selection/Culling
# Removing features that do not correlate well with general_health variable (threshold at correlation factor < |0.05|)

# %%
print("Mean by reported health level:")
display(lab_processed_data.groupby('general_health').mean())
print('\n')
print("Standard Deviation by reported health level:")
lab_processed_data.groupby('general_health').std()
# Out:
# Mean by reported health level:
#                         SEQN  testosterone  estradiol  \
# general_health
# 1.0             88765.766149    235.903841  92.126418
# 2.0             88669.231010    212.660737  85.921147
# 3.0             88690.054416    195.180639  39.285267
#
#                 sex_hormone_binding_globulin  glycohemoglobin  \
# general_health
# 1.0                                64.120686         5.484927
# 2.0                                58.623530         5.715505
# 3.0                                54.718241         6.220662
#
#                 blood_urea_nitrogen  bicarbonate   calcium  cholesterol  \
# general_health
# 1.0                       13.906860    24.464196  9.412218   183.255383
# 2.0                       14.046470    24.428954  9.371001   188.300715
# 3.0                       15.149054    24.399842  9.349132   187.982650
#
#                   chloride     glucose       iron  potassium      sodium  \
# general_health
# ...

# %% [markdown]
# #### Correlates with general_health
# with a marked threshold of |0.05| correlation coefficient (Pearson's r) with general_health <br>

# %%
(lab_processed_data.corr()['general_health'][2:]).plot.bar()
plt.axhline(y = 0.05, linestyle='--')
plt.axhline(y=0, linestyle='-', color='k', alpha=0.5)
plt.axhline(y = -0.05, linestyle='--')
plt.title("Feature correlation with general_health assessment");

# %%
lab_corr_df = pd.DataFrame(lab_processed_data.corr()['general_health'][2:]).abs().sort_values(by='general_health', 
                                                                           ascending=False)
display(lab_corr_df)
# Out:
#                               general_health
# glycohemoglobin                     0.244153
# glucose                             0.196361
# triglycerides                       0.132909
# iron                                0.100573
# uric_acid                           0.094559
# blood_urea_nitrogen                 0.076583
# sex_hormone_binding_globulin        0.073113
# calcium                             0.070629
# testosterone                        0.065035
# sodium                              0.049557
# cholesterol                         0.046466
# chloride                            0.037747
# estradiol                           0.031752
# total_protein                       0.029526
# bicarbonate                         0.011362
# potassium                           0.005326

# %% [markdown]
# ### Analyze features that correlate with general_health
# - Keeping only the features that make the |0.05| correlation-coefficient threshold for correlating with general_health (see the lab_corr_df above)

# %%
lab_correlating_features = list(lab_corr_df[lab_corr_df['general_health'] > 0.05].index)
print("Features to keep are:", lab_correlating_features)
lab_selected_features = lab_processed_data[['general_health'] + lab_correlating_features]
lab_selected_features.head()
# Out:
# Features to keep are: ['glycohemoglobin', 'glucose', 'triglycerides', 'iron', 'uric_acid', 'blood_urea_nitrogen', 'sex_hormone_binding_globulin', 'calcium', 'testosterone']
#    general_health  glycohemoglobin  glucose  triglycerides   iron  uric_acid  \
# 0             2.0              7.0     94.0          158.0   70.0        4.2
# 1             1.0              5.5     94.0          170.0  161.0        7.0
# 2             3.0              5.8    103.0          299.0   72.0        7.3
# 3             2.0              5.6     63.0           93.0   43.0        5.4
# 5             2.0              5.9     97.0           52.0   75.0        4.9
#
#    blood_urea_nitrogen  sex_hormone_binding_globulin  calcium  testosterone
# 0                 13.0                         42.86      9.8        367.00
# 1                 10.0                         29.04      9.8        505.00
# 2                 26.0                         27.02      9.7        104.00
# ...

# %% [markdown]
# ### Visualizing Individual Columns with general_health

# %% [markdown]
# #### Glycohemoglobin
# - Noticeable trend of higher glycohemoglobin levels correlating with lower-perception of general health
# - Each group of general_health looks roughly normal in glycohemoglobin distribution, however, long right tails do seem to be present

# %%
kde_by_category(lab_selected_features, 'general_health', 'glycohemoglobin')

# %%
visualize(lab_selected_features, 'general_health', 'glycohemoglobin')

# %% [markdown]
# #### Glucose
# - Noticeable trend of higher glucose levels correlating with lower-perception of general health
# - Fair amount of variance in 'poor' category
# - Roughly normally distributed (long right tails)
# - Possible outliers present

# %%
kde_by_category(lab_selected_features, 'general_health', 'glucose')

# %%
visualize(lab_selected_features, 'general_health', 'glucose')

# %% [markdown]
# #### Triglycerides
# - Noticeable trend of higher triglycerides levels correlating with lower-perception of general health
# - Fair amount of variance in this data
# - Roughly normally distributed, except levels 4 and 5 seem to have a small secondary peak just under 500 units (possibly bimodal)
# - Possible outliers present

# %%
kde_by_category(lab_selected_features, 'general_health', 'triglycerides')

# %%
visualize(lab_selected_features, 'general_health', 'triglycerides')

# %% [markdown]
# #### Iron
# - Noticeable trend of lower iron levels correlating with lower-perception of general health
# - Distributions look roughly normal
# - Fair amount of variance for the poor health category

# %%
kde_by_category(lab_selected_features, 'general_health', 'iron')

# %%
visualize(lab_selected_features, 'general_health', 'iron')

# %% [markdown]
# #### Uric Acid
# - Noticeable trend of higher uric acid levels correlating with lower-perception of general health
# - Roughly normal (long right tail)
# - Fair amount of variance in this data (particularly the 'poor' category)

# %%
kde_by_category(lab_selected_features, 'general_health', 'uric_acid')

# %%
visualize(lab_selected_features, 'general_health', 'uric_acid')

# %% [markdown]
# #### Blood Urea Nitrogen
# - Noticeable trend of higher Blood-Urea-Nitrogen levels correlating with lower-perception of general health
# - Roughly normal; however, levels 4 and 5 appear to auxilliary peaks (and long right tails on all)
# - Fair amount of variance in this data (particularly the 'poor' category)

# %%
kde_by_category(lab_selected_features, 'general_health', 'blood_urea_nitrogen')

# %%
visualize(lab_selected_features, 'general_health', 'blood_urea_nitrogen')

# %% [markdown]
# #### Testosterone
# - Noticeable trend of lower testerone levels correlating with lower-perception of general health
# - Bimodal distribution, both which seem to be normal by themselves.
# - Fair amount of variance in this data as a whole
# - Possible outliers

# %%
kde_by_category(lab_selected_features, 'general_health', 'testosterone')

# %%
visualize(lab_selected_features, 'general_health', 'testosterone')

# %% [markdown]
# #### Calcium
# - Statistical trend of lower calcium levels correlating with lower-perception of general health
#     - May be difficult to visualize because the variance in the data is much smaller than the variances of other features
# - Roughly normal distributions

# %%
kde_by_category(lab_selected_features, 'general_health', 'calcium')

# %%
visualize(lab_selected_features, 'general_health', 'calcium')

# %% [markdown]
# #### Sex Hormone Binding Globulin
# - Fair amount of variance in this data (particularly the 'exellent' and 'poor' categories)
# - Overall trend appears to be lower SHBG, lower perception of general health; however, the uptick in SHBG for the 'poor' category may lead to this feature not being as helpful in the models
# - Roughly normal distributions (long right tails)

# %%
kde_by_category(lab_selected_features, 'general_health', 'sex_hormone_binding_globulin')

# %%
visualize(lab_selected_features, 'general_health', 'sex_hormone_binding_globulin')

# %% [markdown]
# ### Any Colinearity?
# ** All Correlation Coefficients presented are Pearson's r ** <br>
# The most concerning trends:
# - Glucose and Glycohemoglobin are highly correlated (.79)
# - Uric acid is correlated with a number of other features (including nearly |0.30| for blood_urea_nitrogen, SHBG, and testosterone
# - Testosterone is correlated with iron at .29
# - Triglycerides are correlated with Glucose and Glycohemoglib at ~0.2

# %% [markdown]
# #### Heatmap

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data=lab_selected_features.corr(), vmin=-.5, vmax=.5, cmap='seismic', annot=True);

# %% [markdown]
# # IV. Modeling with Lab-based Data

# %% [markdown]
# #### Class Priors for general health

# %%
lab_priors_pct = lab_selected_features['general_health'].value_counts(normalize=True)
print(lab_priors_pct)

lab_priors = np.array( [lab_priors_pct.tolist()[1], lab_priors_pct.tolist()[0], lab_priors_pct.tolist()[2]] )
# Out:
# 2.0    0.406687
# 1.0    0.362893
# 3.0    0.230420
# Name: general_health, dtype: float64

# %% [markdown]
# #### Model Construction

# %%
# Set up metric lists
lab_linreg_bal_acc = []
lab_linreg_prec = []

lab_knn_bal_acc = []
lab_knn_prec = []

lab_knn_sc_bal_acc = []
lab_knn_sc_prec = []

lab_lr_bal_acc = []
lab_lr_prec = []

lab_lr_t_bal_acc = []
lab_lr_t_prec = []

lab_lda_bal_acc = []
lab_lda_prec = []

lab_lda_t_bal_acc = []
lab_lda_t_prec = []

lab_qda_bal_acc = []
lab_qda_prec = []

lab_qda_t_bal_acc = []
lab_qda_t_prec = []

lab_rf_bal_acc = []
lab_rf_prec = []

lab_rf_t_bal_acc = []
lab_rf_t_prec = []

lab_vc_bal_acc = []
lab_vc_prec = []

lab_vc_t_bal_acc = []
lab_vc_t_prec = []

lab_gb_bal_acc = []
lab_gb_prec = []

lab_gb_t_bal_acc = []
lab_gb_t_prec = []

# Number of iterations
cycles = 25;

for _ in range(cycles):
    ###########################################################################################
    ##################### Split Data
    ###########################################################################################
    
    # Stratified training/testing data
    (lab_X_train, lab_X_test, 
    lab_y_train, lab_y_test) = data_splitter(lab_selected_features.drop('general_health', axis=1), 
                                              lab_selected_features['general_health'])
    
    # Scaled & Stratified training/testing data
    (sc_lab_X_train, sc_lab_X_test, 
    sc_lab_y_train, sc_lab_y_test) = scaled_data_splitter(lab_selected_features.drop('general_health', axis=1), 
                                                          lab_selected_features['general_health'])
    
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Weak Learners ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    
    ###########################################################################################
    ##################### Linear Regression-Based Classification
    ###########################################################################################

    lab_linreg = LinearRegression(n_jobs=-1)
    lab_linreg_m = lab_linreg.fit(lab_X_train, lab_y_train)

    lab_linreg_pred = lab_linreg_m.predict(lab_X_test)
    lab_linreg_pred = lab_linreg_pred.round(0)
    
    lab_linreg_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_linreg_pred) )
    lab_linreg_prec.append( precision_score(lab_y_test, lab_linreg_pred, average='macro') )
    
    ###########################################################################################
    ##################### KNN
    ###########################################################################################
    
    lab_knn = KNeighborsClassifier(n_jobs=-1)

    lab_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    lab_knn_ba, lab_knn_p = grid_search_wrap(lab_knn, lab_knn_params, 
                                             lab_X_train, lab_y_train, lab_X_test, lab_y_test)
    lab_knn_bal_acc.append(lab_knn_ba[0])
    lab_knn_prec.append(lab_knn_p)
    
    ###########################################################################################
    ##################### KNN (Scaled)
    ###########################################################################################
    
    lab_sc_knn = KNeighborsClassifier(n_jobs=-1)

    lab_sc_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    lab_knn_sc_ba, lab_knn_sc_p = grid_search_wrap(lab_sc_knn, lab_sc_knn_params, 
                                                   sc_lab_X_train, sc_lab_y_train, sc_lab_X_test, sc_lab_y_test)
    lab_knn_sc_bal_acc.append(lab_knn_sc_ba[0])
    lab_knn_sc_prec.append(lab_knn_sc_p)


    ###########################################################################################
    ##################### Logistic Regression
    ###########################################################################################
    
    lab_lr = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    lab_lr_params = {
        'C': [0.1, 1, 10, 100],
    }

    # Model and append metrics
    lab_lr_ba, lab_lr_p = grid_search_wrap(lab_lr, lab_lr_params,
                                           lab_X_train, lab_y_train, lab_X_test, lab_y_test)
    lab_lr_bal_acc.append(lab_lr_ba[0])
    lab_lr_prec.append(lab_lr_p)
    
    ###########################################################################################
    ##################### Logistic Regression (Altered Classification Threshold)
    ###########################################################################################
    
    lab_lr_t = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    lab_lr_t_params = {
    'C': [0.1, 1, 10, 100],
    }
    
    # Model and append metrics
    lab_lr_t_ba, lab_lr_t_p = grid_search_wrap(lab_lr_t, lab_lr_t_params, 
                                               lab_X_train, lab_y_train, lab_X_test, lab_y_test,
                                               altered_threshold=True, threshold=.27)
    lab_lr_t_bal_acc.append(lab_lr_t_ba[0])
    lab_lr_t_prec.append(lab_lr_t_p)

    ###########################################################################################
    ##################### LDA
    ###########################################################################################
    
    lab_lda = LinearDiscriminantAnalysis()

    lab_lda_params = {
        'priors' : [None, lab_priors],
    }

    # Model and append metrics
    lab_lda_ba, lab_lda_p = grid_search_wrap(lab_lda, lab_lda_params, lab_X_train, lab_y_train, lab_X_test, lab_y_test)
    lab_lda_bal_acc.append(lab_lda_ba[0])
    lab_lda_prec.append(lab_lda_p)
    
    ###########################################################################################
    ##################### LDA (Altered Classification Threshold)
    ###########################################################################################
    
    lab_lda_t = LinearDiscriminantAnalysis()

    lab_lda_t_params = {
        'priors' : [None, lab_priors],
    }
    
    # Model and append metrics
    lab_lda_t_ba, lab_lda_t_p = grid_search_wrap(lab_lda_t, lab_lda_t_params, 
                                               lab_X_train, lab_y_train, lab_X_test, lab_y_test,
                                               altered_threshold=True, threshold=.27)
    lab_lda_t_bal_acc.append(lab_lda_t_ba[0])
    lab_lda_t_prec.append(lab_lda_t_p)

    ###########################################################################################
    ##################### QDA
    ###########################################################################################
    
    lab_qda = QuadraticDiscriminantAnalysis()

    lab_qda_params = {
        'priors' : [None, lab_priors],
    }
    
    # Model and append metrics
    lab_qda_ba, lab_qda_p = grid_search_wrap(lab_qda, lab_qda_params, 
                                             lab_X_train, lab_y_train, lab_X_test, lab_y_test)
    lab_qda_bal_acc.append(lab_qda_ba[0])
    lab_qda_prec.append(lab_qda_p)
    
    ###########################################################################################
    ##################### QDA (Altered Classification Threshold)
    ###########################################################################################        
    
    lab_qda_t = QuadraticDiscriminantAnalysis()

    lab_qda_t_params = {
        'priors' : [None, lab_priors],
    }
    
    # Model and append metrics
    lab_qda_t_ba, lab_qda_t_p = grid_search_wrap(lab_qda_t, lab_qda_t_params, 
                                                 lab_X_train, lab_y_train, lab_X_test, lab_y_test)
    lab_qda_t_bal_acc.append(lab_qda_t_ba[0])
    lab_qda_t_prec.append(lab_qda_t_p)
   

    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Ensemble Methods ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

    ###########################################################################################
    ##################### Random Forest (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    lab_rf = RandomForestClassifier(n_estimators=50, max_depth=100, max_features=2, n_jobs=-1)
    lab_rf_m = lab_rf.fit(lab_X_train, lab_y_train)
    
    # Normal Predicting / Metrics
    lab_rf_pred = lab_rf.predict(lab_X_test)
    lab_rf_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_rf_pred) )
    lab_rf_prec.append( precision_score(lab_y_test, lab_rf_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    lab_rf_t_pred = predict_w_treshold(lab_rf, lab_X_test, class_num=3, threshold=0.27)
    lab_rf_t_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_rf_t_pred) )
    lab_rf_t_prec.append( precision_score(lab_y_test, lab_rf_t_pred, average='macro') )
    
    ###########################################################################################
    ##################### Voting Classifier (Soft Voting) (Normal/Altered Threshold)
    ###########################################################################################
    # These Hyperparamters were chosen from GridSearching the individual models above
    clf1 = sklearn.ensemble.RandomForestClassifier(n_estimators=50)
    clf2 = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(priors=lab_priors)
    clf3 = sklearn.linear_model.LogisticRegressionCV()
    clf4 = sklearn.neighbors.KNeighborsClassifier(n_neighbors=25)

    lab_vc = sklearn.ensemble.VotingClassifier(estimators=[('rf', clf1), ('lda', clf2), ('lr', clf3), ('knn', clf4)],
                                              n_jobs=-1, voting='soft')

    lab_vc_model = lab_vc.fit(lab_X_train, lab_y_train)
    
    # Normal Predicting / Metrics
    lab_vc_pred = lab_vc.predict(lab_X_test)
    lab_vc_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_vc_pred) )
    lab_vc_prec.append( precision_score(lab_y_test, lab_vc_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    lab_vc_t_pred = predict_w_treshold(lab_vc, lab_X_test, class_num=3, threshold=0.27)
    lab_vc_t_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_vc_t_pred) )
    lab_vc_t_prec.append( precision_score(lab_y_test, lab_vc_t_pred, average='macro') )    
    
    ###########################################################################################
    ##################### Gradient Boosting (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    lab_gb = GradientBoostingClassifier(max_features=2, n_estimators=50)
    
    lab_gb_m = lab_gb.fit(lab_X_train, lab_y_train)
    
    # Normal Predicting / Metrics
    lab_gb_pred = lab_gb.predict(lab_X_test)
    lab_gb_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_gb_pred) )
    lab_gb_prec.append( precision_score(lab_y_test, lab_gb_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    lab_gb_t_pred = predict_w_treshold(lab_gb, lab_X_test, class_num=3, threshold=0.27)
    lab_gb_t_bal_acc.append( balanced_accuracy_score(lab_y_test, lab_gb_t_pred) )
    lab_gb_t_prec.append( precision_score(lab_y_test, lab_gb_t_pred, average='macro') ) 
    
    ###########################################################################################
    ##################### Print Status
    ###########################################################################################
    clear_output() # Ensures only one line of text is printed at once
    display( str(_+1) + " Out of " + str(cycles) + " completed . . .")

clear_output()
print("Modeling Complete.")
# Out:
# Modeling Complete.

# %% [markdown]
# #### Model Performances

# %%
###########################################################################################
##################### Balanced Accuracies
###########################################################################################
lab_model_bas = pd.DataFrame({'Lin_Reg_Classifier': lab_linreg_bal_acc,
                              'KNN': lab_knn_bal_acc,
                              'KNN_Scaled': lab_knn_sc_bal_acc,
                              'Log_Reg': lab_lr_bal_acc,
                              'Log_Reg_ACT': lab_lr_t_bal_acc,
                              'LDA': lab_lda_bal_acc,
                              'LDA_ACT': lab_qda_t_bal_acc,
                              'QDA': lab_qda_bal_acc,
                              'QDA_ACT': lab_qda_t_bal_acc,
                              'Random_Forest': lab_rf_bal_acc,
                              'Random_Forest_ACT': lab_rf_t_bal_acc,
                              'Voting_Classifier': lab_vc_bal_acc,
                              'Voting_Classifier_ACT': lab_vc_t_bal_acc,
                              'Gradient_Boost': lab_gb_bal_acc,
                              'Gradient_Boost_ACT': lab_gb_t_bal_acc})

# Rearrange Column Order
lmb_cols = list(lab_model_bas.columns.values)
lmb_cols = lmb_cols[2:] + lmb_cols[:2]
lab_model_bas = lab_model_bas[lmb_cols]

###########################################################################################
##################### Precisions (Macro-Averaged)
###########################################################################################
lab_model_precs = pd.DataFrame({'Lin_Reg_Classifier': lab_linreg_prec,
                                'KNN': lab_knn_prec,
                                'KNN_Scaled': lab_knn_sc_prec,
                                'Log_Reg': lab_lr_prec,
                                'Log_Reg_ACT': lab_lr_t_prec,
                                'LDA': lab_lda_prec,
                                'LDA_ACT': lab_qda_t_prec,
                                'QDA': lab_qda_prec,
                                'QDA_ACT': lab_qda_t_prec,
                                'Random_Forest': lab_rf_prec,
                                'Random_Forest_ACT': lab_rf_t_prec,
                                'Voting_Classifier': lab_vc_prec,
                                'Voting_Classifier_ACT': lab_vc_t_prec,
                                'Gradient_Boost': lab_gb_prec,
                                'Gradient_Boost_ACT': lab_gb_t_prec})

# Rearrange Column Order
lmp_cols = list(lab_model_precs.columns.values)
lmp_cols = lmp_cols[2:] + lmp_cols[:2]
lab_model_precs = lab_model_precs[lmp_cols]


###########################################################################################
##################### Plotting
###########################################################################################
lab_ba_fig, (lab_ba_ax, lab_prec_ax) = plt.subplots(2, 1, figsize=(15,15))
lab_model_bas.boxplot(ax=lab_ba_ax)

# Plotting Balanced Accuracies
plt.sca(lab_ba_ax)
plt.title("Balanced Accuracies of Classification Models for General Health Assessment\n" \
          "(Sample Size: "+ str(len(lab_model_bas)) + " Trials)" \
          + "\nBlack Line: Weak Learner - Ensemble Method Split" \
          + "\nRed Line: Theoretical Balanced Accuracy for only majority class classification / random classification by class frequency")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axhline(0.33, linestyle='--', color='r') # Only Guessing Majority Class / Random Classification based on class freq
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.ylabel("Balanced Accuracy (%)")
plt.xticks(rotation=-90)

# Plotting Precisions
plt.sca(lab_prec_ax)
lab_model_precs.boxplot(ax=lab_prec_ax)
plt.title("Precisions (Macro Averaged) of Classification Models using Lab Data for General Health Assessment\n" \
          "(Sample Size: "+ str(len(lab_model_bas)) + " Trials)" \
         + "\nBlack Line: Weak Learner - Ensemble Method Split")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.xticks(rotation=-90)
plt.ylabel("Precision (%)");

# Need more space between the subplots
plt.subplots_adjust(hspace=0.6)

# %% [markdown]
# # V. Exploring Sociological-based Data

# %%
socio_data_url = 'https://raw.githubusercontent.com/oconnoag/NHANES_Data/master/compiled_data/flor_compiled_raw.csv'
raw_data = pd.read_csv(socio_data_url)

# %% [markdown]
# ### Column Renaming

# %%
processed_data_a = raw_data.copy()

# %%
processed_data_b = processed_data_a.rename(columns={'HSD010': 'general_health',
                                                    'RIDAGEYR': 'age',
                                                    'DMDHHSIZ': 'people_in_household',
                                                    'INDHHIN2': 'annual_income',
                                                    'DBQ700': 'healthy_diet',
                                                    'DBD900': 'number_meals_fastfood_past7',
                                                    'DBD910': 'number_frozen_past30',
                                                    'BMXBMI': 'bmi',
                                                    'PAQ635': 'walk_or_bike',
                                                    'PAQ650': 'vigorous_rec', 
                                                    'PAD680': 'sedentary',
                                                    })

# %%
processed_data_c = processed_data_b.copy()
processed_data_c['general_health'] = processed_data_b['general_health']\
                                            .apply(lambda x: general_health_reclasser(x))

# %% [markdown]
# ### Cleaning Data

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8887 entries, 0 to 8886
# Data columns (total 12 columns):
# SEQN        8887 non-null float64
# HSD010      6166 non-null float64
# RIDAGEYR    8887 non-null float64
# DMDHHSIZ    8887 non-null float64
# INDHHIN2    8618 non-null float64
# DBQ700      6063 non-null float64
# DBD900      6757 non-null float64
# DBD910      8821 non-null float64
# BMXBMI      8756 non-null float64
# PAQ635      6701 non-null float64
# PAQ650      6699 non-null float64
# PAD680      6687 non-null float64
# dtypes: float64(12)
# memory usage: 833.2 KB

# %%
processed_data = processed_data_c.copy()

# %%
# Drop any subject with empty values
processed_data = processed_data.dropna()

processed_data = processed_data[processed_data['annual_income'] < 77]
processed_data = processed_data[processed_data['healthy_diet'] != 9]
processed_data = processed_data[processed_data['vigorous_rec'] != 9]

# %%
processed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3997 entries, 0 to 8886
# Data columns (total 12 columns):
# SEQN                           3997 non-null float64
# general_health                 3997 non-null float64
# age                            3997 non-null float64
# people_in_household            3997 non-null float64
# annual_income                  3997 non-null float64
# healthy_diet                   3997 non-null float64
# number_meals_fastfood_past7    3997 non-null float64
# number_frozen_past30           3997 non-null float64
# bmi                            3997 non-null float64
# walk_or_bike                   3997 non-null float64
# vigorous_rec                   3997 non-null float64
# sedentary                      3997 non-null float64
# dtypes: float64(12)
# memory usage: 405.9 KB

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### General Health Distribution

# %%
processed_data['general_health'].hist(grid=False, bins=np.arange(0,7,1)-0.5, ec='k')
plt.xlim([0,4])
plt.title('Breakdown (# of subjects in each)\n of General Health Levels')
plt.ylabel("Freq")
plt.xlabel("Current Health Level")
plt.xticks(np.arange(1,4), ['1 - Better', '2 - Good', '3 - Worse'],
          rotation=90);

# %% [markdown]
# ### Feature Selection/Culling

# %%
print("Mean by reported health level:")
display(processed_data.groupby('general_health').mean())
print('\n')
print("Standard Deviation by reported health level:")
processed_data.groupby('general_health').std()
# Out:
# Mean by reported health level:
#                         SEQN        age  people_in_household  annual_income  \
# general_health
# 1.0             88696.008276  41.708966             3.282759      10.128966
# 2.0             88706.578757  44.839469             3.383826       9.080266
# 3.0             88694.877528  48.369663             3.420225       7.271910
#
#                 healthy_diet  number_meals_fastfood_past7  \
# general_health
# 1.0                 2.642759                     1.893103
# 2.0                 3.204587                     5.482800
# 3.0                 3.698876                     2.378652
#
#                 number_frozen_past30        bmi  walk_or_bike  vigorous_rec  \
# general_health
# 1.0                         7.133103  26.924828      1.760690      1.544138
# 2.0                        10.675920  29.801267      1.780326      1.737477
# 3.0                        17.666292  32.476742      1.795506      1.847191
#
#                  sedentary
# ...

# %% [markdown]
# #### Correlates with general_health
# with a marked threshold of |0.05| correlation coefficient (Pearson's r) with general_health <br>

# %%
(processed_data.corr()['general_health'][2:]).plot.bar()
plt.axhline(y = 0.05, linestyle='--')
plt.axhline(y=0, linestyle='-', color='k', alpha=0.5)
plt.axhline(y = -0.05, linestyle='--')
plt.title("Feature correlation with general_health assessment");

# %%
corr_df = pd.DataFrame(processed_data.corr()['general_health'][2:]).abs().sort_values(by='general_health', 
                                                                           ascending=False)
display(corr_df)
# Out:
#                              general_health
# healthy_diet                       0.396901
# bmi                                0.290815
# vigorous_rec                       0.253826
# annual_income                      0.241623
# age                                0.129829
# people_in_household                0.032186
# sedentary                          0.032017
# walk_or_bike                       0.031849
# number_frozen_past30               0.016247
# number_meals_fastfood_past7        0.005020

# %% [markdown]
# ### Analyze features that correlate with general_health
# - Keeping only the features that make the |0.05| correlation-coefficient threshold for correlating with general_health (see the corr_df above)

# %%
correlating_features = list(corr_df[corr_df['general_health'] > 0.05].index)
print("Features to keep are:", correlating_features)
selected_features = processed_data[['general_health'] + correlating_features]
selected_features.head()
# Out:
# Features to keep are: ['healthy_diet', 'bmi', 'vigorous_rec', 'annual_income', 'age']
#    general_health  healthy_diet   bmi  vigorous_rec  annual_income   age
# 0             2.0           3.0  27.8           2.0           10.0  62.0
# 2             3.0           4.0  28.8           2.0            5.0  78.0
# 3             2.0           4.0  42.4           2.0           10.0  56.0
# 4             3.0           5.0  20.3           2.0            7.0  42.0
# 5             2.0           3.0  28.6           2.0           14.0  72.0

# %% [markdown]
# ### Visualizing Individual Columns with general_health

# %% [markdown]
# #### Healthy Diet
#
# - Noticeable trend of having a healthy diet correlating with higher-perception of general health
# - Less variance at the poor and excellent health values
# - Medium general health values possibly multimodal
# - Possible outliers present, especially at the medium values 2-4

# %%
# set width of bar
barWidth = 0.10
 
# set height of bar
count_1 = list(selected_features[selected_features['healthy_diet'] == 1].groupby(by=['general_health'])['healthy_diet'].count())
bars1 = np.array(count_1) / sum(count_1)

count_2 = list(selected_features[selected_features['healthy_diet'] == 2].groupby(by=['general_health'])['healthy_diet'].count())
bars2 = np.array(count_2) / sum(count_2)

count_3 = list(selected_features[selected_features['healthy_diet'] == 3].groupby(by=['general_health'])['healthy_diet'].count())
bars3 = np.array(count_3) / sum(count_3)

count_4 = list(selected_features[selected_features['healthy_diet'] == 4].groupby(by=['general_health'])['healthy_diet'].count())
bars4 = np.array(count_4) / sum(count_4)

count_5 = list(selected_features[selected_features['healthy_diet'] == 5].groupby(by=['general_health'])['healthy_diet'].count())
bars5 = np.array(count_5) / sum(count_5)

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
 
# Make the plot
plt.figure(figsize=(14,4))
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='3')
plt.bar(r4, bars4, color='#AA4371', width=barWidth, edgecolor='white', label='4')
plt.bar(r5, bars5, color='#A6761D', width=barWidth, edgecolor='white', label='5')
 
# Add xticks on the middle of the group bars
plt.xlabel('general_health', fontweight='bold')
plt.xticks([r + barWidth*2 for r in range(len(bars1))], ['1', '2', '3', '4', '5']) 
    
# Create legend & Show graphic
plt.legend(title='healthy_diet', bbox_to_anchor=(1,1))
plt.show()

# %%
visualize(selected_features, 'general_health', 'healthy_diet')

# %% [markdown]
# #### Vigorous Exercise
#
# - Noticeable trend of reporting vigorous exercise and higher-perception of general health, with most respondents who exercise in the 1-3 general health ratings

# %%
# set width of bar
barWidth = 0.33
 
# set height of bar
count_1 = list(selected_features[selected_features['vigorous_rec'] == 1].groupby(by=['general_health'])['vigorous_rec'].count())
bars1 = np.array(count_1) / sum(count_1)

count_2 = list(selected_features[selected_features['vigorous_rec'] == 2].groupby(by=['general_health'])['vigorous_rec'].count())
bars2 = np.array(count_2) / sum(count_2)


# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.figure(figsize=(14,4))
plt.bar(r1, bars1, color='blue', alpha=0.5, width=barWidth, edgecolor='white', label='Yes')
plt.bar(r2, bars2, color='red', alpha=0.5, width=barWidth, edgecolor='white', label='No')
 
# Add xticks on the middle of the group bars
plt.xlabel('general_health', fontweight='bold')
plt.xticks([r + barWidth * .5 for r in range(len(bars1))], ['1', '2', '3', '4', '5'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
visualize_categorical(selected_features, 'general_health', 'vigorous_rec')

# %% [markdown]
# #### BMI
# - Noticeable trend of BMI values between ~20-~30 correlating with higher-perception of general health
# - Fair amount of variance in this data
# - Significant number of outliers especially in 1-4 health perception levels

# %%
kde_by_category(selected_features, 'general_health', 'bmi')

# %%
visualize(selected_features, 'general_health', 'bmi')

# %% [markdown]
# #### Annual Income
# - General trend of lower income levels correlating with higher-perception of general health
# - Distribution possibly bimodal

# %%
kde_by_category(selected_features, 'general_health', 'annual_income')

# %%
visualize(selected_features, 'general_health', 'annual_income')

# %% [markdown]
# #### Age
# - Noticeable peak of lower-perception of general health in young ages (might be affected by small sample size)
# - Highest perceptions of general health (values 4 and 5) skewed to the left
# - Possible outliers

# %%
kde_by_category(selected_features, 'general_health', 'age')

# %%
visualize(selected_features, 'general_health', 'age')

# %% [markdown]
# ### Any Colinearity?
# ** All Correlation Coefficients presented are Pearson's r ** <br>
# The most concerning trends:
# - Vigorous recreation and age are highly correlated (.35)
# - Healthy diet is correlated with BMI (0.23)
# - Vigorous recreation is also correlated with BMI (.18)

# %% [markdown]
# #### Heatmap

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data=selected_features.corr(), vmin=-.5, vmax=.5, cmap='seismic', annot=True);

# %% [markdown]
# ## VI. Modeling with Sociological-based Data

# %%
socio_priors_pct = selected_features['general_health'].value_counts(normalize=True)
print(socio_priors_pct)

socio_priors = np.array( [socio_priors_pct.tolist()[1], socio_priors_pct.tolist()[0], socio_priors_pct.tolist()[2]] )
# Out:
# 2.0    0.414561
# 1.0    0.362772
# 3.0    0.222667
# Name: general_health, dtype: float64

# %% [markdown]
# #### Model Building

# %%
# Set up metric lists
socio_linreg_bal_acc = []
socio_linreg_prec = []

socio_knn_bal_acc = []
socio_knn_prec = []

socio_knn_sc_bal_acc = []
socio_knn_sc_prec = []

socio_lr_bal_acc = []
socio_lr_prec = []

socio_lr_t_bal_acc = []
socio_lr_t_prec = []

socio_lda_bal_acc = []
socio_lda_prec = []

socio_lda_t_bal_acc = []
socio_lda_t_prec = []

socio_qda_bal_acc = []
socio_qda_prec = []

socio_qda_t_bal_acc = []
socio_qda_t_prec = []

socio_rf_bal_acc = []
socio_rf_prec = []

socio_rf_t_bal_acc = []
socio_rf_t_prec = []

socio_vc_bal_acc = []
socio_vc_prec = []

socio_vc_t_bal_acc = []
socio_vc_t_prec = []

socio_gb_bal_acc = []
socio_gb_prec = []

socio_gb_t_bal_acc = []
socio_gb_t_prec = []

# Number of iterations
cycles = 25;

for _ in range(cycles):
    ###########################################################################################
    ##################### Split Data
    ###########################################################################################
    
    # Stratified training/testing data
    (socio_X_train, socio_X_test, 
    socio_y_train, socio_y_test) = data_splitter(selected_features.drop('general_health', axis=1), 
                                              selected_features['general_health'])
    
    # Scaled & Stratified training/testing data
    (sc_socio_X_train, sc_socio_X_test, 
    sc_socio_y_train, sc_socio_y_test) = scaled_data_splitter(selected_features.drop('general_health', axis=1), 
                                                          selected_features['general_health'])
    
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Weak Learners ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    
    ###########################################################################################
    ##################### Linear Regression-Based Classification
    ###########################################################################################

    socio_linreg = LinearRegression(n_jobs=-1)
    socio_linreg_m = socio_linreg.fit(socio_X_train, socio_y_train)

    socio_linreg_pred = socio_linreg_m.predict(socio_X_test)
    socio_linreg_pred = socio_linreg_pred.round(0)
    
    socio_linreg_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_linreg_pred) )
    socio_linreg_prec.append( precision_score(socio_y_test, socio_linreg_pred, average='macro') )
    
    ###########################################################################################
    ##################### KNN
    ###########################################################################################
    
    socio_knn = KNeighborsClassifier(n_jobs=-1)

    socio_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    socio_knn_ba, socio_knn_p = grid_search_wrap(socio_knn, socio_knn_params, 
                                             socio_X_train, socio_y_train, socio_X_test, socio_y_test)
    socio_knn_bal_acc.append(socio_knn_ba[0])
    socio_knn_prec.append(socio_knn_p)
    
    ###########################################################################################
    ##################### KNN (Scaled)
    ###########################################################################################
    
    socio_sc_knn = KNeighborsClassifier(n_jobs=-1)

    socio_sc_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    socio_knn_sc_ba, socio_knn_sc_p = grid_search_wrap(socio_sc_knn, socio_sc_knn_params, 
                                                   sc_socio_X_train, sc_socio_y_train, sc_socio_X_test, sc_socio_y_test)
    socio_knn_sc_bal_acc.append(socio_knn_sc_ba[0])
    socio_knn_sc_prec.append(socio_knn_sc_p)


    ###########################################################################################
    ##################### Logistic Regression
    ###########################################################################################
    
    socio_lr = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    socio_lr_params = {
        'C': [0.1, 1, 10, 100],
    }

    # Model and append metrics
    socio_lr_ba, socio_lr_p = grid_search_wrap(socio_lr, socio_lr_params,
                                           socio_X_train, socio_y_train, socio_X_test, socio_y_test)
    socio_lr_bal_acc.append(socio_lr_ba[0])
    socio_lr_prec.append(socio_lr_p)
    
    ###########################################################################################
    ##################### Logistic Regression (Altered Classification Threshold)
    ###########################################################################################
    
    socio_lr_t = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    socio_lr_t_params = {
    'C': [0.1, 1, 10, 100],
    }
    
    # Model and append metrics
    socio_lr_t_ba, socio_lr_t_p = grid_search_wrap(socio_lr_t, socio_lr_t_params, 
                                               socio_X_train, socio_y_train, socio_X_test, socio_y_test,
                                               altered_threshold=True, threshold=.27)
    socio_lr_t_bal_acc.append(socio_lr_t_ba[0])
    socio_lr_t_prec.append(socio_lr_t_p)

    ###########################################################################################
    ##################### LDA
    ###########################################################################################
    
    socio_lda = LinearDiscriminantAnalysis()

    socio_lda_params = {
        'priors' : [None, socio_priors],
    }

    # Model and append metrics
    socio_lda_ba, socio_lda_p = grid_search_wrap(socio_lda, socio_lda_params, socio_X_train, socio_y_train, socio_X_test, socio_y_test)
    socio_lda_bal_acc.append(socio_lda_ba[0])
    socio_lda_prec.append(socio_lda_p)
    
    ###########################################################################################
    ##################### LDA (Altered Classification Threshold)
    ###########################################################################################
    
    socio_lda_t = LinearDiscriminantAnalysis()

    socio_lda_t_params = {
        'priors' : [None, socio_priors],
    }
    
    # Model and append metrics
    socio_lda_t_ba, socio_lda_t_p = grid_search_wrap(socio_lda_t, socio_lda_t_params, 
                                               socio_X_train, socio_y_train, socio_X_test, socio_y_test,
                                               altered_threshold=True, threshold=.27)
    socio_lda_t_bal_acc.append(socio_lda_t_ba[0])
    socio_lda_t_prec.append(socio_lda_t_p)

    ###########################################################################################
    ##################### QDA
    ###########################################################################################
    
    socio_qda = QuadraticDiscriminantAnalysis()

    socio_qda_params = {
        'priors' : [None, socio_priors],
    }
    
    # Model and append metrics
    socio_qda_ba, socio_qda_p = grid_search_wrap(socio_qda, socio_qda_params, 
                                             socio_X_train, socio_y_train, socio_X_test, socio_y_test)
    socio_qda_bal_acc.append(socio_qda_ba[0])
    socio_qda_prec.append(socio_qda_p)
    
    ###########################################################################################
    ##################### QDA (Altered Classification Threshold)
    ###########################################################################################        
    
    socio_qda_t = QuadraticDiscriminantAnalysis()

    socio_qda_t_params = {
        'priors' : [None, socio_priors],
    }
    
    # Model and append metrics
    socio_qda_t_ba, socio_qda_t_p = grid_search_wrap(socio_qda_t, socio_qda_t_params, 
                                                 socio_X_train, socio_y_train, socio_X_test, socio_y_test)
    socio_qda_t_bal_acc.append(socio_qda_t_ba[0])
    socio_qda_t_prec.append(socio_qda_t_p)
   

    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Ensemble Methods ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

    ###########################################################################################
    ##################### Random Forest (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    socio_rf = RandomForestClassifier(n_estimators=50, max_depth=100, max_features=2, n_jobs=-1)
    socio_rf_m = socio_rf.fit(socio_X_train, socio_y_train)
    
    # Normal Predicting / Metrics
    socio_rf_pred = socio_rf.predict(socio_X_test)
    socio_rf_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_rf_pred) )
    socio_rf_prec.append( precision_score(socio_y_test, socio_rf_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    socio_rf_t_pred = predict_w_treshold(socio_rf, socio_X_test, class_num=3, threshold=0.27)
    socio_rf_t_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_rf_t_pred) )
    socio_rf_t_prec.append( precision_score(socio_y_test, socio_rf_t_pred, average='macro') )
    
    ###########################################################################################
    ##################### Voting Classifier (Soft Voting) (Normal/Altered Threshold)
    ###########################################################################################
    # These Hyperparamters were chosen from GridSearching the individual models above
    clf1 = sklearn.ensemble.RandomForestClassifier(n_estimators=50)
    clf2 = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(priors=socio_priors)
    clf3 = sklearn.linear_model.LogisticRegressionCV()
    clf4 = sklearn.neighbors.KNeighborsClassifier(n_neighbors=25)

    socio_vc = sklearn.ensemble.VotingClassifier(estimators=[('rf', clf1), ('lda', clf2), ('lr', clf3), ('knn', clf4)],
                                              n_jobs=-1, voting='soft')

    socio_vc_model = socio_vc.fit(socio_X_train, socio_y_train)
    
    # Normal Predicting / Metrics
    socio_vc_pred = socio_vc.predict(socio_X_test)
    socio_vc_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_vc_pred) )
    socio_vc_prec.append( precision_score(socio_y_test, socio_vc_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    socio_vc_t_pred = predict_w_treshold(socio_vc, socio_X_test, class_num=3, threshold=0.27)
    socio_vc_t_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_vc_t_pred) )
    socio_vc_t_prec.append( precision_score(socio_y_test, socio_vc_t_pred, average='macro') )    
    
    ###########################################################################################
    ##################### Gradient Boosting (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    socio_gb = GradientBoostingClassifier(max_features=2, n_estimators=50)
    
    socio_gb_m = socio_gb.fit(socio_X_train, socio_y_train)
    
    # Normal Predicting / Metrics
    socio_gb_pred = socio_gb.predict(socio_X_test)
    socio_gb_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_gb_pred) )
    socio_gb_prec.append( precision_score(socio_y_test, socio_gb_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    socio_gb_t_pred = predict_w_treshold(socio_gb, socio_X_test, class_num=3, threshold=0.27)
    socio_gb_t_bal_acc.append( balanced_accuracy_score(socio_y_test, socio_gb_t_pred) )
    socio_gb_t_prec.append( precision_score(socio_y_test, socio_gb_t_pred, average='macro') ) 
    
    ###########################################################################################
    ##################### Print Status
    ###########################################################################################
    clear_output() # Ensures only one line of text is printed at once
    display( str(_+1) + " Out of " + str(cycles) + " completed . . .")

clear_output()
print("Modeling Complete.")
# Out:
# Modeling Complete.

# %% [markdown]
# #### Model Performance

# %%
###########################################################################################
##################### Balanced Accuracies
###########################################################################################
socio_model_bas = pd.DataFrame({'Lin_Reg_Classifier': socio_linreg_bal_acc,
                              'KNN': socio_knn_bal_acc,
                              'KNN_Scaled': socio_knn_sc_bal_acc,
                              'Log_Reg': socio_lr_bal_acc,
                              'Log_Reg_ACT': socio_lr_t_bal_acc,
                              'LDA': socio_lda_bal_acc,
                              'LDA_ACT': socio_qda_t_bal_acc,
                              'QDA': socio_qda_bal_acc,
                              'QDA_ACT': socio_qda_t_bal_acc,
                              'Random_Forest': socio_rf_bal_acc,
                              'Random_Forest_ACT': socio_rf_t_bal_acc,
                              'Voting_Classifier': socio_vc_bal_acc,
                              'Voting_Classifier_ACT': socio_vc_t_bal_acc,
                              'Gradient_Boost': socio_gb_bal_acc,
                              'Gradient_Boost_ACT': socio_gb_t_bal_acc})

# Rearrange Column Order
cmb_cols = list(socio_model_bas.columns.values)
cmb_cols = cmb_cols[2:] + cmb_cols[:2]
socio_model_bas = socio_model_bas[cmb_cols]

###########################################################################################
##################### Precisions (Macro-Averaged)
###########################################################################################
socio_model_precs = pd.DataFrame({'Lin_Reg_Classifier': socio_linreg_prec,
                                'KNN': socio_knn_prec,
                                'KNN_Scaled': socio_knn_sc_prec,
                                'Log_Reg': socio_lr_prec,
                                'Log_Reg_ACT': socio_lr_t_prec,
                                'LDA': socio_lda_prec,
                                'LDA_ACT': socio_qda_t_prec,
                                'QDA': socio_qda_prec,
                                'QDA_ACT': socio_qda_t_prec,
                                'Random_Forest': socio_rf_prec,
                                'Random_Forest_ACT': socio_rf_t_prec,
                                'Voting_Classifier': socio_vc_prec,
                                'Voting_Classifier_ACT': socio_vc_t_prec,
                                'Gradient_Boost': socio_gb_prec,
                                'Gradient_Boost_ACT': socio_gb_t_prec})

# Rearrange Column Order
cmp_cols = list(socio_model_precs.columns.values)
cmp_cols = cmp_cols[2:] + cmp_cols[:2]
socio_model_precs = socio_model_precs[cmp_cols]


###########################################################################################
##################### Plotting
###########################################################################################
socio_ba_fig, (socio_ba_ax, socio_prec_ax) = plt.subplots(2, 1, figsize=(15,15))
socio_model_bas.boxplot(ax=socio_ba_ax)

# Plotting Balanced Accuracies
plt.sca(socio_ba_ax)
plt.title("Balanced Accuracies of Classification Models using Sociology Data for General Health Assessment\n" \
          "(Sample Size: "+ str(len(socio_model_bas)) + " Trials)" \
          + "\nBlack Line: Weak Learner - Ensemble Method Split" \
          + "\nRed Line: Theoretical Balanced Accuracy for only majority class classification / random classification by class frequency")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axhline(0.33, linestyle='--', color='r') # Only Guessing Majority Class / Random Classification based on class freq
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.ylabel("Balanced Accuracy (%)")
plt.xticks(rotation=-90)

# Plotting Precisions
plt.sca(socio_prec_ax)
socio_model_precs.boxplot(ax=socio_prec_ax)
plt.title("Precisions (Macro Averaged) of Classification Models using Sociology Data for General Health Assessment\n" \
          "(Sample Size: "+ str(len(socio_model_bas)) + " Trials)" \
         + "\nBlack Line: Weak Learner - Ensemble Method Split")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.xticks(rotation=-90)
plt.ylabel("Precision (%)");

# Need more space between the subplots
plt.subplots_adjust(hspace=0.6)

# %% [markdown]
# # VII. Modeling with Combined Data

# %% [markdown]
# #### Merge Datasets

# %%
combined_data = pd.merge(lab_processed_data, processed_data, how='inner')

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3599 entries, 0 to 3598
# Data columns (total 28 columns):
# SEQN                            3599 non-null float64
# general_health                  3599 non-null float64
# testosterone                    3599 non-null float64
# estradiol                       3599 non-null float64
# sex_hormone_binding_globulin    3599 non-null float64
# glycohemoglobin                 3599 non-null float64
# blood_urea_nitrogen             3599 non-null float64
# bicarbonate                     3599 non-null float64
# calcium                         3599 non-null float64
# cholesterol                     3599 non-null float64
# chloride                        3599 non-null float64
# glucose                         3599 non-null float64
# iron                            3599 non-null float64
# potassium                       3599 non-null float64
# sodium                          3599 non-null float64
# ...

# %%
# Set up DataFrame with only the selected features from the lab and socio data, respectively
combined_selected_features = combined_data[lab_selected_features.columns.tolist() \
                                  + selected_features.drop('general_health', axis=1).columns.tolist()]

# %%
combined_selected_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3599 entries, 0 to 3598
# Data columns (total 15 columns):
# general_health                  3599 non-null float64
# glycohemoglobin                 3599 non-null float64
# glucose                         3599 non-null float64
# triglycerides                   3599 non-null float64
# iron                            3599 non-null float64
# uric_acid                       3599 non-null float64
# blood_urea_nitrogen             3599 non-null float64
# sex_hormone_binding_globulin    3599 non-null float64
# calcium                         3599 non-null float64
# testosterone                    3599 non-null float64
# healthy_diet                    3599 non-null float64
# bmi                             3599 non-null float64
# vigorous_rec                    3599 non-null float64
# annual_income                   3599 non-null float64
# age                             3599 non-null float64
# dtypes: float64(15)
# memory usage: 449.9 KB

# %% [markdown]
# #### Class Priors for General Health

# %%
combined_priors_pct = combined_selected_features['general_health'].value_counts(normalize=True)
print(combined_priors_pct)

combined_priors = np.array( [combined_priors_pct.tolist()[1], combined_priors_pct.tolist()[0], combined_priors_pct.tolist()[2]] )
# Out:
# 2.0    0.415115
# 1.0    0.361767
# 3.0    0.223118
# Name: general_health, dtype: float64

# %% [markdown]
# #### Model Building

# %%
# Set up metric lists
combined_linreg_bal_acc = []
combined_linreg_prec = []

combined_knn_bal_acc = []
combined_knn_prec = []

combined_knn_sc_bal_acc = []
combined_knn_sc_prec = []

combined_lr_bal_acc = []
combined_lr_prec = []

combined_lr_t_bal_acc = []
combined_lr_t_prec = []

combined_lda_bal_acc = []
combined_lda_prec = []

combined_lda_t_bal_acc = []
combined_lda_t_prec = []

combined_qda_bal_acc = []
combined_qda_prec = []

combined_qda_t_bal_acc = []
combined_qda_t_prec = []

combined_rf_bal_acc = []
combined_rf_prec = []

combined_rf_t_bal_acc = []
combined_rf_t_prec = []

combined_vc_bal_acc = []
combined_vc_prec = []

combined_vc_t_bal_acc = []
combined_vc_t_prec = []

combined_gb_bal_acc = []
combined_gb_prec = []

combined_gb_t_bal_acc = []
combined_gb_t_prec = []

# Number of iterations
cycles = 25;

for _ in range(cycles):
    ###########################################################################################
    ##################### Split Data
    ###########################################################################################
    
    # Stratified training/testing data
    (combined_X_train, combined_X_test, 
    combined_y_train, combined_y_test) = data_splitter(combined_selected_features.drop('general_health', axis=1), 
                                              combined_selected_features['general_health'])
    
    # Scaled & Stratified training/testing data
    (sc_combined_X_train, sc_combined_X_test, 
    sc_combined_y_train, sc_combined_y_test) = scaled_data_splitter(combined_selected_features.drop('general_health', axis=1), 
                                                          combined_selected_features['general_health'])
    
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Weak Learners ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    
    ###########################################################################################
    ##################### Linear Regression-Based Classification
    ###########################################################################################

    combined_linreg = LinearRegression(n_jobs=-1)
    combined_linreg_m = combined_linreg.fit(combined_X_train, combined_y_train)

    combined_linreg_pred = combined_linreg_m.predict(combined_X_test)
    combined_linreg_pred = combined_linreg_pred.round(0)
    
    combined_linreg_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_linreg_pred) )
    combined_linreg_prec.append( precision_score(combined_y_test, combined_linreg_pred, average='macro') )
    
    ###########################################################################################
    ##################### KNN
    ###########################################################################################
    
    combined_knn = KNeighborsClassifier(n_jobs=-1)

    combined_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    combined_knn_ba, combined_knn_p = grid_search_wrap(combined_knn, combined_knn_params, 
                                             combined_X_train, combined_y_train, combined_X_test, combined_y_test)
    combined_knn_bal_acc.append(combined_knn_ba[0])
    combined_knn_prec.append(combined_knn_p)
    
    ###########################################################################################
    ##################### KNN (Scaled)
    ###########################################################################################
    
    combined_sc_knn = KNeighborsClassifier(n_jobs=-1)

    combined_sc_knn_params = {
        'n_neighbors': [10, 15, 20, 25]
    }

    # Model and append metrics
    combined_knn_sc_ba, combined_knn_sc_p = grid_search_wrap(combined_sc_knn, combined_sc_knn_params, 
                                                   sc_combined_X_train, sc_combined_y_train, sc_combined_X_test, sc_combined_y_test)
    combined_knn_sc_bal_acc.append(combined_knn_sc_ba[0])
    combined_knn_sc_prec.append(combined_knn_sc_p)


    ###########################################################################################
    ##################### Logistic Regression
    ###########################################################################################
    
    combined_lr = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    combined_lr_params = {
        'C': [0.1, 1, 10, 100],
    }

    # Model and append metrics
    combined_lr_ba, combined_lr_p = grid_search_wrap(combined_lr, combined_lr_params,
                                           combined_X_train, combined_y_train, combined_X_test, combined_y_test)
    combined_lr_bal_acc.append(combined_lr_ba[0])
    combined_lr_prec.append(combined_lr_p)
    
    ###########################################################################################
    ##################### Logistic Regression (Altered Classification Threshold)
    ###########################################################################################
    
    combined_lr_t = LogisticRegression(solver='lbfgs', multi_class='multinomial', n_jobs=-1)

    combined_lr_t_params = {
    'C': [0.1, 1, 10, 100],
    }
    
    # Model and append metrics
    combined_lr_t_ba, combined_lr_t_p = grid_search_wrap(combined_lr_t, combined_lr_t_params, 
                                               combined_X_train, combined_y_train, combined_X_test, combined_y_test,
                                               altered_threshold=True, threshold=.27)
    combined_lr_t_bal_acc.append(combined_lr_t_ba[0])
    combined_lr_t_prec.append(combined_lr_t_p)

    ###########################################################################################
    ##################### LDA
    ###########################################################################################
    
    combined_lda = LinearDiscriminantAnalysis()

    combined_lda_params = {
        'priors' : [None, combined_priors],
    }

    # Model and append metrics
    combined_lda_ba, combined_lda_p = grid_search_wrap(combined_lda, combined_lda_params, combined_X_train, combined_y_train, combined_X_test, combined_y_test)
    combined_lda_bal_acc.append(combined_lda_ba[0])
    combined_lda_prec.append(combined_lda_p)
    
    ###########################################################################################
    ##################### LDA (Altered Classification Threshold)
    ###########################################################################################
    
    combined_lda_t = LinearDiscriminantAnalysis()

    combined_lda_t_params = {
        'priors' : [None, combined_priors],
    }
    
    # Model and append metrics
    combined_lda_t_ba, combined_lda_t_p = grid_search_wrap(combined_lda_t, combined_lda_t_params, 
                                               combined_X_train, combined_y_train, combined_X_test, combined_y_test,
                                               altered_threshold=True, threshold=.27)
    combined_lda_t_bal_acc.append(combined_lda_t_ba[0])
    combined_lda_t_prec.append(combined_lda_t_p)

    ###########################################################################################
    ##################### QDA
    ###########################################################################################
    
    combined_qda = QuadraticDiscriminantAnalysis()

    combined_qda_params = {
        'priors' : [None, combined_priors],
    }
    
    # Model and append metrics
    combined_qda_ba, combined_qda_p = grid_search_wrap(combined_qda, combined_qda_params, 
                                             combined_X_train, combined_y_train, combined_X_test, combined_y_test)
    combined_qda_bal_acc.append(combined_qda_ba[0])
    combined_qda_prec.append(combined_qda_p)
    
    ###########################################################################################
    ##################### QDA (Altered Classification Threshold)
    ###########################################################################################        
    
    combined_qda_t = QuadraticDiscriminantAnalysis()

    combined_qda_t_params = {
        'priors' : [None, combined_priors],
    }
    
    # Model and append metrics
    combined_qda_t_ba, combined_qda_t_p = grid_search_wrap(combined_qda_t, combined_qda_t_params, 
                                                 combined_X_train, combined_y_train, combined_X_test, combined_y_test)
    combined_qda_t_bal_acc.append(combined_qda_t_ba[0])
    combined_qda_t_prec.append(combined_qda_t_p)
   

    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Ensemble Methods ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#
    #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~#

    ###########################################################################################
    ##################### Random Forest (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    combined_rf = RandomForestClassifier(n_estimators=50, max_depth=100, max_features=2, n_jobs=-1)
    combined_rf_m = combined_rf.fit(combined_X_train, combined_y_train)
    
    # Normal Predicting / Metrics
    combined_rf_pred = combined_rf.predict(combined_X_test)
    combined_rf_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_rf_pred) )
    combined_rf_prec.append( precision_score(combined_y_test, combined_rf_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    combined_rf_t_pred = predict_w_treshold(combined_rf, combined_X_test, class_num=3, threshold=0.27)
    combined_rf_t_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_rf_t_pred) )
    combined_rf_t_prec.append( precision_score(combined_y_test, combined_rf_t_pred, average='macro') )
    
    ###########################################################################################
    ##################### Voting Classifier (Soft Voting) (Normal/Altered Threshold)
    ###########################################################################################
    # These Hyperparamters were chosen from GridSearching the individual models above
    clf1 = sklearn.ensemble.RandomForestClassifier(n_estimators=50)
    clf2 = sklearn.discriminant_analysis.LinearDiscriminantAnalysis(priors=combined_priors)
    clf3 = sklearn.linear_model.LogisticRegressionCV()
    clf4 = sklearn.neighbors.KNeighborsClassifier(n_neighbors=25)

    combined_vc = sklearn.ensemble.VotingClassifier(estimators=[('rf', clf1), ('lda', clf2), ('lr', clf3), ('knn', clf4)],
                                              n_jobs=-1, voting='soft')

    combined_vc_model = combined_vc.fit(combined_X_train, combined_y_train)
    
    # Normal Predicting / Metrics
    combined_vc_pred = combined_vc.predict(combined_X_test)
    combined_vc_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_vc_pred) )
    combined_vc_prec.append( precision_score(combined_y_test, combined_vc_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    combined_vc_t_pred = predict_w_treshold(combined_vc, combined_X_test, class_num=3, threshold=0.27)
    combined_vc_t_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_vc_t_pred) )
    combined_vc_t_prec.append( precision_score(combined_y_test, combined_vc_t_pred, average='macro') )    
    
    ###########################################################################################
    ##################### Gradient Boosting (Normal/Altered Threshold)
    ###########################################################################################
    # These hyperparameters were selected using GridSearching outside of this loop -- just too 
    # slow to have run many times
    combined_gb = GradientBoostingClassifier(max_features=2, n_estimators=50)
    
    combined_gb_m = combined_gb.fit(combined_X_train, combined_y_train)
    
    # Normal Predicting / Metrics
    combined_gb_pred = combined_gb.predict(combined_X_test)
    combined_gb_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_gb_pred) )
    combined_gb_prec.append( precision_score(combined_y_test, combined_gb_pred, average='macro') )
    
    # Threshold Altered Predicting / Metrics
    combined_gb_t_pred = predict_w_treshold(combined_gb, combined_X_test, class_num=3, threshold=0.27)
    combined_gb_t_bal_acc.append( balanced_accuracy_score(combined_y_test, combined_gb_t_pred) )
    combined_gb_t_prec.append( precision_score(combined_y_test, combined_gb_t_pred, average='macro') ) 
    
    ###########################################################################################
    ##################### Print Status
    ###########################################################################################
    clear_output() # Ensures only one line of text is printed at once
    display( str(_+1) + " Out of " + str(cycles) + " completed . . .")

clear_output()
print("Modeling Complete.")
# Out:
# Modeling Complete.

# %% [markdown]
# #### Model Performances

# %%
###########################################################################################
##################### Balanced Accuracies
###########################################################################################
combined_model_bas = pd.DataFrame({'Lin_Reg_Classifier': combined_linreg_bal_acc,
                              'KNN': combined_knn_bal_acc,
                              'KNN_Scaled': combined_knn_sc_bal_acc,
                              'Log_Reg': combined_lr_bal_acc,
                              'Log_Reg_ACT': combined_lr_t_bal_acc,
                              'LDA': combined_lda_bal_acc,
                              'LDA_ACT': combined_qda_t_bal_acc,
                              'QDA': combined_qda_bal_acc,
                              'QDA_ACT': combined_qda_t_bal_acc,
                              'Random_Forest': combined_rf_bal_acc,
                              'Random_Forest_ACT': combined_rf_t_bal_acc,
                              'Voting_Classifier': combined_vc_bal_acc,
                              'Voting_Classifier_ACT': combined_vc_t_bal_acc,
                              'Gradient_Boost': combined_gb_bal_acc,
                              'Gradient_Boost_ACT': combined_gb_t_bal_acc})

# Rearrange Column Order
cmb_cols = list(combined_model_bas.columns.values)
cmb_cols = cmb_cols[2:] + cmb_cols[:2]
combined_model_bas = combined_model_bas[cmb_cols]

###########################################################################################
##################### Precisions (Macro-Averaged)
###########################################################################################
combined_model_precs = pd.DataFrame({'Lin_Reg_Classifier': combined_linreg_prec,
                                'KNN': combined_knn_prec,
                                'KNN_Scaled': combined_knn_sc_prec,
                                'Log_Reg': combined_lr_prec,
                                'Log_Reg_ACT': combined_lr_t_prec,
                                'LDA': combined_lda_prec,
                                'LDA_ACT': combined_qda_t_prec,
                                'QDA': combined_qda_prec,
                                'QDA_ACT': combined_qda_t_prec,
                                'Random_Forest': combined_rf_prec,
                                'Random_Forest_ACT': combined_rf_t_prec,
                                'Voting_Classifier': combined_vc_prec,
                                'Voting_Classifier_ACT': combined_vc_t_prec,
                                'Gradient_Boost': combined_gb_prec,
                                'Gradient_Boost_ACT': combined_gb_t_prec})

# Rearrange Column Order
cmp_cols = list(combined_model_precs.columns.values)
cmp_cols = cmp_cols[2:] + cmp_cols[:2]
combined_model_precs = combined_model_precs[cmp_cols]


###########################################################################################
##################### Plotting
###########################################################################################
combined_ba_fig, (combined_ba_ax, combined_prec_ax) = plt.subplots(2, 1, figsize=(15,15))
combined_model_bas.boxplot(ax=combined_ba_ax)

# Plotting Balanced Accuracies
plt.sca(combined_ba_ax)
plt.title("Balanced Accuracies of Classification Models using Combined Data for General Health Assessment\n" \
          "(Sample Size: "+ str(len(combined_model_bas)) + " Trials)" \
          + "\nBlack Line: Weak Learner - Ensemble Method Split" \
          + "\nRed Line: Theoretical Balanced Accuracy for only majority class classification / random classification by class frequency")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axhline(0.33, linestyle='--', color='r') # Only Guessing Majority Class / Random Classification based on class freq
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.ylabel("Balanced Accuracy (%)")
plt.xticks(rotation=-90)

# Plotting Precisions
plt.sca(combined_prec_ax)
combined_model_precs.boxplot(ax=combined_prec_ax)
plt.title("Precisions (Macro Averaged) of Classification Models using Combined Data for General Health Assessment\n" \
          "(Sample Size: "+ str(len(combined_model_bas)) + " Trials)" \
         + "\nBlack Line: Weak Learner - Ensemble Method Split")
plt.grid(alpha=0.33, linestyle='--', color='gray')
plt.axvline(9.5, linestyle='--', color='k') # Splits the weak learners from ensemble methods
plt.xticks(rotation=-90)
plt.ylabel("Precision (%)");

# Need more space between the subplots
plt.subplots_adjust(hspace=0.6)

# %% [markdown]
# #### Example of Model Differences when using the Altered Classification Thresholds

# %%
cgb = GradientBoostingClassifier(max_features=2, n_estimators=50)

cgb_m = cgb.fit(combined_X_train, combined_y_train)

# Normal Predicting / Metrics
cgb_pred = cgb.predict(combined_X_test)
print(confusion_matrix(combined_y_test, cgb_pred))
print()
print(classification_report(combined_y_test, cgb_pred))

print('\n------------------------------------------------------------')
print('--------- W/ Altered Classification Threshold --------------')
print('------------------------------------------------------------\n')

# Threshold Altered Predicting / Metrics
cgb_t_pred = predict_w_treshold(cgb, combined_X_test, class_num=3, threshold=0.27)
print(confusion_matrix(combined_y_test, cgb_t_pred))
print()
print(classification_report(combined_y_test, cgb_t_pred))
# Out:
# [[165  89   6]
#  [ 71 195  33]
#  [ 17  78  66]]
#
#               precision    recall  f1-score   support
#
#          1.0       0.65      0.63      0.64       260
#          2.0       0.54      0.65      0.59       299
#          3.0       0.63      0.41      0.50       161
#
#    micro avg       0.59      0.59      0.59       720
#    macro avg       0.61      0.57      0.58       720
# weighted avg       0.60      0.59      0.59       720
#
#
# ------------------------------------------------------------
# --------- W/ Altered Classification Threshold --------------
# ------------------------------------------------------------
#
# [[164  65  31]
#  [ 69 149  81]
#  [ 17  37 107]]
#
#               precision    recall  f1-score   support
#
#          1.0       0.66      0.63      0.64       260
#          2.0       0.59      0.50      0.54       299
#          3.0       0.49      0.66      0.56       161
#
#    micro avg       0.58      0.58      0.58       720
# ...

# %% [markdown]
# # VIII. Conclusion & Discussion

# %% [markdown]
# To summarize our work, we have obtained raw data from the CDC's NHANES 2015-2016 <a href='https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?BeginYear=2015'>publicly released repository</a>.  Those files were originally in xpt format, which we converted to csv using a simple shell script -- the generated csv files were stored in a repository on Alijah O'Connor's Github (https://github.com/oconnoag/NHANES_Data).  Features were selected from certain files in this repository by both authors and compiled into csv files, respectively (a list of the features and their original files can be found in the <a href='#II.a-Data-Description'>data description section</a> of this file).  The compiled files are stored in a subdirectory in that same GitHub repo (https://github.com/oconnoag/NHANES_Data/tree/master/compiled_data).  Data Preparation, Cleaning, and Exploratory data analysis (ADA) was performed by each author on our respective compiled datasets, analyzing the features that were selected.  A modeling pipeline was created and used to assess the relative performances of many different classification models -- Each model was built 25 times (using different training/test data on each iteration), hyperparamter optimized for that iteration using Scikit-learn's GridSearch prodecure with 5-fold cross validation, and finally, the balanced accurracy and precisions (macro-averaged) were collected. The analysis files for this project can be found in a separate Github repo also on Alijah O'Connor's account (https://github.com/oconnoag/NHANES_General_Health_Prediction).
#
# Interestingly, even after applying scaling transformations where needed, stratified data splitting, and hyperparameter, we found the lab-based based did a relatively poor job at predicting in subjective general health assessment with any of the models (even the ensemble methods did not perform in an acceptable manner -- with the gradient boosting having the mean balanced accuracy around ~45%).  The sociology data produced models that did outperform the lab-based models; however, they still weren't ideal models, as the best models were topping out around a mean balanced accuracy of 60%.  Further, it appears as though that the models based off of the combined datasets did not outperform the sociology data by much (if at all); therefore, further data mining might be necessary if one were looking to build a production-ready model that could operate on lab-based data alone or one that could operate on a select number of features from each type of dataset.
#
# It should be noted that the models that utilized the altered classification threshold of 27% for class 3 did perform better (in terms of balanced averages) than their non-altered foundations (see the gradient boosting example above in the combined data modeling section), they performed worse at precision.  As such, if someone wanted to take these methods into production, they would have to assess the trade-off presented -- do they want more class 3 ("worse") people captured at the expense of false classifying people actually in class 1 or class 2 to class 3?  Depends on the application of the model, when it comes down to it.  For example, if it were to be used as a screen to focus efforts on people not doing well, then the practitioner may well want to use the altered threshold to capture as many of these people as possible.  However, perhaps if the institution looking to utilize the model was quite underfunded, maybe they couldn't invest time or resources into filtering the false 'positives' out, so they would prefer to have the higher balanced precision.
#
# So why did the models perform as they did with these datasets?  Because each of the parametric-based weak learning models (e.g. Logistic Regression, LDA/QDA) performed roughly equivalently for each of the datasets, the optimal decision boundaries were likely relatively non-complex.  Further evidence comes from the KNN performance, which was lagging behind these models that assume simpler decision boundaries.  However, due to the fact that none of these models are doing egregiously worse than the others on a consistent basis (except maybe unscaled KNN and linear-regression-based classification), it might be safe to assume that their underlying assumptions are generally holding.  For example, LDA assumes that samples (and mean and variance for calculating the model parameters) are drawn from a gaussian distribution and that all of the features share a common covariance matrix.  QDA allows for a more flexible fit; however, it typically doesn't have drastically impaired performance if the optimal decision boundary is not complex.  What's more QDA assumes that each class has its own covariance matrix; however, if the covariance matrix ends up looking roughly equivalent for each class, then it too won't provide improved performance over LDA.
#
# As for the ensemble methods, gradient boosting appears to be the most performant model for dataset.  This makes intuitive sense, because gradient boosting puts a lot of emphasis on classifying the "difficult to classify" data points, of which our datasets consist (biology/subjective data often create contradictory data points for the models to deal with).  Random Forests and Voting Classifiers, on the other hand, rely on the power of those weak learner models to a larger degree, since they are composed of many of them.  Therefore, if those weak learning models are only hitting a particular point of accuracy (and they all are hitting about the same point, even after cross validation), you may see a similar ceiling for stacking/boosting performance.
#
# With all of this in mind, one may wonder, why the combined data-based models don't outperform the sociology-only models.  It's hard to say for certain, but it could be simply that the sociology-data is able to get to an 'optimal'-decision boundary without the help of the lab-based data, so these features cannot add any helpful information for further separating the observations in the classes.  The models can only be as good as the data (and hyperparamters, I suppose) will let them be.
#
# In conclusion, our models for predicting subjective assessment of general health leave something to be desired.  As stated before, subjective measurements are difficult to "objectify" by their very nature.  In the future, more features ought to be vetted and considered in the modeling process (perhaps with more datapoints as well).  Because NHANES conducts these studies every year, it may be possible to expand the datasets to include multiple years of measurements -- this presents an appealing way to get more of these precious samples; however, at the expense of the analysts/data scientists that have to clean and prepare those merged datasets while retaining as many of those samples as possible.

# %% [markdown]
# # IX. References

# %% [markdown]
# Hunt, S. M., McEwen, J., & McKenna, S. P. (1985). Measuring health status: a new tool for clinicians and epidemiologists. JR Coll Gen Pract, 35(273), 185-188.
#
# Donges, Niklas (2018). The Random Forest Algorithm.  https://towardsdatascience.com/the-random-forest-algorithm-d457d499ffcd
#
# Bowne-Anderson, Hugo (2016). Preprocessing in Data Science (Part 1): Centering, Scaling, and KNN. https://www.datacamp.com/community/tutorials/preprocessing-in-data-science-part-1-centering-scaling-and-knn
#
# Bowne-Anderson, Hugo (2016). Preprocessing in Data Science (Part 2): Centering, Scaling and Logistic Regression.
# https://www.datacamp.com/community/tutorials/preprocessing-in-data-science-part-2-centering-scaling-and-logistic-regression
#
# Koehrsen, Will (2018). Hyperparameter Tuning the Random Forest in Python. https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
#
# Arvai, Kevin (2018). Fine tuning a classifier in scikit-learn.
# https://towardsdatascience.com/fine-tuning-a-classifier-in-scikit-learn-66e048c21e65
